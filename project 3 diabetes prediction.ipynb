# %% [markdown]
# <h2> DIABETES PREDICTION
# <H4> Importing data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("D:\projects\datasets\diabetes.csv")
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# <H4> no null values present

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# <h4> Exploratory Data Analysis

# %%
data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
data['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# <h4> from corelation it is clear that o/p high depends on glucose

# %%
import seaborn as sns
sns.lmplot(x='Glucose',y='BMI',hue='Outcome',data=data,fit_reg=False)

# %%
import seaborn as sns
sns.lmplot(x='Glucose',y='Insulin',hue='Outcome',data=data,fit_reg=False)

# %% [markdown]
# <h4> model building

# %%
from sklearn.cross_validation import train_test_split
x=data.drop(['Outcome'],axis=1)
y=data['Outcome']
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2)
print(train_y.shape)
# Out:
# (614,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC,LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

# %%
m1=LogisticRegression()
m1.fit(train_x , train_y)
p1=m1.predict(test_x)
a1=accuracy_score(test_y,p1)
print(a1)
# Out:
# 0.7792207792207793

# %%
m2=DecisionTreeClassifier()
m2.fit(train_x,train_y)
p2=m2.predict(test_x)
a2=accuracy_score(test_y,p2)
print(a2)
# Out:
# 0.6818181818181818

# %%
m3=RandomForestClassifier()
m3.fit(train_x,train_y)
p3=m3.predict(test_x)
a3=accuracy_score(test_y,p3)
print(a3)
# Out:
# 0.7792207792207793

# %%
m4=SVC()
m4.fit(train_x,train_y)
p4=m4.predict(test_x)
a4=accuracy_score(test_y,p4)
print(a4)
# Out:
# 0.7337662337662337

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
k_range = list(range(1,26))
scores = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(train_x,train_y)
    y_pred = knn.predict(test_x)
    scores.append(metrics.accuracy_score(test_y, y_pred))
    
plt.plot(k_range, scores)
plt.xlabel('Value of k for KNN')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores for Values of k of k-Nearest-Neighbors')
plt.show()

# %%
m5=KNeighborsClassifier(n_neighbors=16)
m5.fit(train_x,train_y)
p5=m5.predict(test_x)
a5=accuracy_score(test_y,p5)
print(a5)
# Out:
# 0.7857142857142857

# %%
m7=GaussianNB()
m7.fit(train_x,train_y)
p7=m7.predict(test_x)
a7=accuracy_score(test_y,p7)
print(a7)
# Out:
# 0.7727272727272727

# %%
m6=XGBClassifier()
m6.fit(train_x,train_y)
p6=m6.predict(test_x)
a6=accuracy_score(test_y,p6)
print(a6)
# Out:
# 0.7532467532467533
# D:\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
params={
    "learning_rate":[0.05,0.10,0.15,0.2,0.25,0.3],
    "max_depth":[1,4,6,8,10,15] ,
    "min_child_weight":[1,3,5,7] ,
    "gamma":[0.1,0.2,0.3,0.4] ,
    "n_estimators":[100,200,300,400,500]
}
from sklearn.model_selection import RandomizedSearchCV , GridSearchCV
r_s=RandomizedSearchCV(m6,param_distributions=params,n_iter=5,n_jobs=-1)
r_s.fit(train_x,train_y)
r_s.best_params_
r_s.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0.1,
#        learning_rate=0.05, max_delta_step=0, max_depth=6,
#        min_child_weight=1, missing=None, n_estimators=400, n_jobs=1,
#        nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, subsample=1, verbosity=1)

# %%
m8=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
       colsample_bynode=1, colsample_bytree=1, gamma=0.1,
       learning_rate=0.05, max_delta_step=0, max_depth=6,
       min_child_weight=1, missing=None, n_estimators=400, n_jobs=1,
       nthread=None, objective='binary:logistic', random_state=0,
       reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
       silent=None, subsample=1, verbosity=1)

m8.fit(train_x,train_y)
p8=m8.predict(test_x)
a8=accuracy_score(test_y,p8)
print(a8)
# Out:
# 0.7207792207792207
# D:\anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
